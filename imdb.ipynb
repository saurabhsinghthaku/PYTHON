# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\saura\OneDrive\Desktop\IMDB-Movie-Data.csv')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
pd.options.display.float_format='{:.2f}'.format

# %%
df.describe()
# Out:
#          Rank    Year  Runtime (Minutes)  Rating      Votes  \
# count  838.00  838.00             838.00  838.00     838.00
# mean   485.25 2012.51             114.64    6.81  193230.25
# std    286.57    3.17              18.47    0.88  193099.01
# min      1.00 2006.00              66.00    1.90     178.00
# 25%    238.25 2010.00             101.00    6.30   61276.50
# 50%    475.50 2013.00             112.00    6.90  136879.50
# 75%    729.75 2015.00             124.00    7.50  271083.00
# max   1000.00 2016.00             187.00    9.00 1791916.00
#
#        Revenue (Millions)  Metascore
# count              838.00     838.00
# mean                84.56      59.58
# std                104.52      16.95
# min                  0.00      11.00
# 25%                 13.97      47.00
# 50%                 48.15      60.00
# 75%                116.80      72.00
# max                936.63     100.00

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (838, 12)

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.1+ KB

# %%
df.loc[df['Runtime (Minutes)']>90,'Title']
# Out:
# 0             Guardians of the Galaxy
# 1                          Prometheus
# 2                               Split
# 3                                Sing
# 4                       Suicide Squad
#                     ...
# 990    Underworld: Rise of the Lycans
# 991                  Taare Zameen Par
# 993          Resident Evil: Afterlife
# 996                   Hostel: Part II
# 997            Step Up 2: The Streets
# Name: Title, Length: 790, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.Year
# Out:
# 0      2014
# 1      2012
# 2      2016
# 3      2016
# 4      2016
#        ...
# 993    2010
# 994    2012
# 996    2007
# 997    2008
# 999    2016
# Name: Year, Length: 838, dtype: int64

# %%
df.groupby('Year')['Votes'].mean().sort_values(ascending=False).plot(kind='bar')
sns.barplot(data=df,x='Year',y='Votes')
plt.xlabel('Year',fontsize=15)
plt.ylabel('Avg_Votes',fontsize=15)
# Out:
# Text(0, 0.5, 'Avg_Votes')

# %%
sns.barplot(data=df,x='Year',y='Revenue (Millions)')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue (Millions)'>

# %%
df.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False).head(1)
# Out:
# Year
# 2009   115.74
# Name: Revenue (Millions), dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                  8.68
# Olivier Nakache                    8.60
# Makoto Shinkai                     8.60
# Florian Henckel von Donnersmarck   8.50
# Aamir Khan                         8.50
#                                    ...
# Sam Taylor-Johnson                 4.10
# Joey Curtis                        4.00
# George Nolfi                       3.90
# James Wong                         2.70
# Jason Friedberg                    1.90
# Name: Rating, Length: 524, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.sort_values(by='Runtime (Minutes)',ascending=False).head(10)[['Title','Runtime (Minutes)']]
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 75   Pirates of the Caribbean: At World's End                169
# 36                               Interstellar                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %%
df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Title'>

# %%
df
df.Year.value_counts()
# Out:
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: Year, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Title'>

# %%
df_mov
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
df_mov=df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]

# %%
df_mov
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %%
sns.barplot(x='Runtime (Minutes)',y='Title',data=df_mov)
# plt.xticks(rotation=70)
plt.show()

# %%
# df_mov=df_mov.set_index('Title')
df_mov
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
sns.barplot(data=df_mov,x='Runtime (Minutes)',y=df_mov.index)
# Out:
# <AxesSubplot: xlabel='Runtime (Minutes)', ylabel='Title'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
sns.countplot(data=df,x='Year')
plt.title('Number of movies per Year')
# Out:
# Text(0.5, 1.0, 'Number of movies per Year')

# %%
df.Year.value_counts()
# Out:
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: Year, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df[df['Revenue (Millions)'].max()==df['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df1=df.nlargest(10,'Rank')[['Title','Director','Rank']].set_index('Rank')

# %%
# df1=df.sort_values(by='Rank',ascending=False).head(10)[['Title','Director']]

# %%
df1
sns.barplot(data=df1, x=df1.index, y='Director',hue='Title',dodge=False)
plt.legend(bbox_to_anchor=(1,1.05),loc=2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.groupby('Year')['Rating'].mean().
# Out:
# Year
# 2006   7.14
# 2007   7.14
# 2008   6.71
# 2009   6.91
# 2010   6.89
# 2011   6.95
# 2012   6.93
# 2013   6.83
# 2014   6.82
# 2015   6.67
# 2016   6.64
# Name: Rating, dtype: float64

# %%
sns.barplot(data=df,x='Year',y='Rating')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Rating'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df1=df.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']]

# %%
sns.barplot(data=df1,x='Revenue (Millions)',y='Title')
# df1
# Out:
# <AxesSubplot: xlabel='Revenue (Millions)', ylabel='Title'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_3256\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >

# %%
df.corr()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_18260\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Rank  Year  Runtime (Minutes)  Rating  Votes  \
# Rank                1.00 -0.31              -0.25   -0.24  -0.30
# Year               -0.31  1.00              -0.10   -0.15  -0.36
# Runtime (Minutes)  -0.25 -0.10               1.00    0.37   0.40
# Rating             -0.24 -0.15               0.37    1.00   0.52
# Votes              -0.30 -0.36               0.40    0.52   1.00
# Revenue (Millions) -0.27 -0.13               0.28    0.22   0.64
# Metascore          -0.20 -0.06               0.22    0.67   0.33
#
#                     Revenue (Millions)  Metascore
# Rank                             -0.27      -0.20
# Year                             -0.13      -0.06
# ...

# %%
sns.scatterplot(data=df,x='Rating',y='Revenue (Millions)')
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 117.4+ KB

# %%
df.Rating
# Out:
# 0     8.10
# 1     7.00
# 2     7.30
# 3     7.20
# 4     6.20
#       ...
# 993   5.90
# 994   6.70
# 996   5.50
# 997   6.20
# 999   5.30
# Name: Rating, Length: 838, dtype: float64

# %%
# pd.cut(df['Rating'],labels=['A','B','C'],bins=[10,8,6,4
def rat(rat):
    if (rat >5 and rat<7):
        return 'A'
    elif (rat >=7 and rat<8):
        return 'b'
    elif (rat >=8 and rat<10):
        return 'c'

# %%
df['rating_c']=df.Rating.apply(rat)

# %%
df.insert(4,'ratiiit',df['rating_c'])

# %%
df.drop(columns='ratiii',inplace=True)
df
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description ratiiit  \
# 0    A group of intergalactic criminals are forced ...       c
# 1    Following clues to the origin of mankind, a te...       b
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   ratiiit             815 non-null    object
#  5   Director            838 non-null    object
#  6   Actors              838 non-null    object
#  7   Year                838 non-null    int64
#  8   Runtime (Minutes)   838 non-null    int64
#  9   Rating              838 non-null    float64
#  10  Votes               838 non-null    int64
#  11  Revenue (Millions)  838 non-null    float64
#  12  Metascore           838 non-null    float64
#  13  rating_c            815 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 130.5+ KB

# %%
len(df[df.Genre.str.contains('Action',case=False)])
# Out:
# 277

# %%
# df.Genre
l=[item.split(',') for item in df.Genre]
d=[]
for i in l:
    for y in i if y not in d:
        d.append(y)
# Out:
#   Cell In[2], line 5
#     for y in i if y not in d:
#                             ^
# SyntaxError: invalid syntax

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
# Out:
# ['Mystery,Romance,Thriller',
#  'Drama,Horror,Mystery',
#  'Comedy,Drama,Fantasy',
#  'Action,Comedy,Crime',
#  'Drama,Fantasy,Mystery',
#  'Action,Crime,Thriller',
#  'Drama,Horror,Sci-Fi',
#  'Drama,Fantasy,Thriller',
#  'Crime,Drama,Fantasy',
#  'Action,Adventure,Mystery',
#  'Comedy,Romance,Sport',
#  'Adventure,Comedy,Drama',
#  'Drama,Western',
#  'Adventure,Comedy,Horror',
#  'Crime,Drama,Music',
#  'Sci-Fi,Thriller',
#  'Drama,Mystery,Romance',
#  'Action,Biography,Drama',
#  'Action,Adventure,Western',
#  'Action,Adventure,Comedy',
#  'Comedy,Music',
#  'Action,Comedy,Mystery',
#  'Mystery,Thriller',
#  'Comedy,Drama,Thriller',
#  'Adventure,Drama,Thriller',
#  'Horror,Sci-Fi,Thriller',
#  'Drama,Family,Fantasy',
#  'Action,Comedy,Drama',
#  'Drama,War',
#  'Drama,Sci-Fi',
#  'Drama,Sci-Fi,Thriller',
#  'Action,Drama,Fantasy',
#  'Action,Horror,Mystery',
#  'Fantasy,Horror',
#  'Horror',
#  'Biography,Drama,Mystery',
#  'Action,Drama,History',
#  'Drama,Fantasy,Musical',
# ...

# %%
# Out:
# ['Action,Adventure,Sci-Fi',
#  'Adventure,Mystery,Sci-Fi',
#  'Horror,Thriller',
#  'Animation,Comedy,Family',
#  'Action,Adventure,Fantasy',
#  'Action,Adventure,Fantasy',
#  'Comedy,Drama,Music',
#  'Action,Adventure,Biography',
#  'Adventure,Drama,Romance',
#  'Adventure,Family,Fantasy',
#  'Biography,Drama,History',
#  'Action,Adventure,Sci-Fi',
#  'Animation,Adventure,Comedy',
#  'Action,Comedy,Drama',
#  'Animation,Adventure,Comedy',
#  'Biography,Drama,History',
#  'Action,Thriller',
#  'Biography,Drama',
#  'Drama,Mystery,Sci-Fi',
#  'Adventure,Drama,Thriller',
#  'Drama',
#  'Animation,Adventure,Comedy',
#  'Action,Adventure,Sci-Fi',
#  'Comedy',
#  'Action,Adventure,Drama',
#  'Comedy',
#  'Drama,Thriller',
#  'Action,Adventure,Sci-Fi',
#  'Action,Adventure,Comedy',
#  'Action,Horror,Sci-Fi',
#  'Action,Adventure,Sci-Fi',
#  'Adventure,Drama,Sci-Fi',
#  'Action,Adventure,Fantasy',
#  'Action,Adventure,Western',
#  'Animation,Adventure,Comedy',
#  'Drama',
# ...

# %%
import pandas as pd
df =pd.read_csv(r'C:\Users\saura\OneDrive\Desktop\IMDB-Movie-Data.csv')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df['Year1']=pd.to_datetime(df['Year'])

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                            Year  Runtime (Minutes)  Rating   Votes  \
# 0 1970-01-01 00:00:00.000002014                121     8.1  757074
# 1 1970-01-01 00:00:00.000002012                124     7.0  485820
#
#    Revenue (Millions)  Metascore
# 0              333.13       76.0
# 1              126.46       65.0

# %%
pd.set_option('display.max_rows',5)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# ..    ...                      ...                       ...
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 0    A group of intergalactic criminals are forced ...        James Gunn
# 1    Following clues to the origin of mankind, a te...      Ridley Scott
# ..                                                 ...               ...
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996  Lauren German, Heather Matarazzo, Bijou Philli...
# ...

# %%
df.tail(-5)
# Out:
#      Rank           Title                     Genre  \
# 5       6  The Great Wall  Action,Adventure,Fantasy
# 6       7      La La Land        Comedy,Drama,Music
# ..    ...             ...                       ...
# 998   999    Search Party          Adventure,Comedy
# 999  1000      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 5    European mercenaries searching for black powde...       Yimou Zhang
# 6    A jazz pianist falls for an aspiring actress i...   Damien Chazelle
# ..                                                 ...               ...
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  \
# 5        Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# 6    Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# ...

# %%
df.info('memory_usage')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   datetime64[ns]
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 93.9+ KB

# %%
df.isna().values.any()
# Out:
# True

# %%
pd.set_option('display.max_rows',10)

# %%
df.isna().sum()*100/len(df)
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
#                       ...
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# Length: 12, dtype: float64

# %%
import numpy as np
df.describe(include=[np.number])
# Out:
#               Rank  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000         113.172000     6.723200  1.698083e+05
# std     288.819436          18.810908     0.945429  1.887626e+05
# min       1.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000         100.000000     6.200000  3.630900e+04
# 50%     500.500000         111.000000     6.800000  1.107990e+05
# 75%     750.250000         123.000000     7.400000  2.399098e+05
# max    1000.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
df.shape
# Out:
# (1000, 12)

# %%
print(f'num of rows {df.shape[0]}\
     num of columns {df.shape[1]}')
# Out:
# num of rows 1000     num of columns 12

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isna())
# Out:
# <AxesSubplot: >

# %%
df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
#                      ...
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# Length: 12, dtype: int64

# %%
df['Revenue (Millions)'].dtype()
# Out:
# dtype('float64')

# %%
df['Metascore'].dtype
# Out:
# dtype('float64')

# %%
df['Revenue (Millions)']=df['Revenue (Millions)'].fillna(df['Revenue (Millions)'].mean())

# %%
df.isna().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
#                       ..
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# Length: 12, dtype: int64

# %%
df['Revenue (Millions)']
# Out:
# 0      333.130000
# 1      126.460000
# 2      138.120000
# 3      270.320000
# 4      325.020000
#           ...
# 995     82.956376
# 996     17.540000
# 997     58.010000
# 998     82.956376
# 999     19.640000
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
df.Metascore=df.Metascore.fillna(df.Metascore.mean())

# %%
df.isna().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
#                      ..
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# Length: 12, dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_32904\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
len(df[df['Runtime (Minutes)']>=180])
# Out:
# 5

# %%
df.Year=pd.to_datetime(df.Year)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   datetime64[ns]
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 93.9+ KB

# %%
df_year=df.Year.dt.year

# %%
df['month']=df.Year.dt.month

# %%
df.insert(3,'new_year',df_year)

# %%
df=df.drop('month',axis=1)

# %%
del df['Year1']

# %%
df=df.drop(columns='Year')

# %%
df
# Out:
#      Rank                    Title                     Genre  new_year  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi      1970
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi      1970
# 2       3                    Split           Horror,Thriller      1970
# 3       4                     Sing   Animation,Comedy,Family      1970
# 4       5            Suicide Squad  Action,Adventure,Fantasy      1970
# ..    ...                      ...                       ...       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery      1970
# 996   997          Hostel: Part II                    Horror      1970
# 997   998   Step Up 2: The Streets       Drama,Music,Romance      1970
# 998   999             Search Party          Adventure,Comedy      1970
# 999  1000               Nine Lives     Comedy,Family,Fantasy      1970
#
#                                            Description              Director  \
# ...

# %%
df.rename({"new_year":"Year"},axis=1)
# Out:
#      Rank                    Title                     Genre  Year  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  1970
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi  1970
# 2       3                    Split           Horror,Thriller  1970
# 3       4                     Sing   Animation,Comedy,Family  1970
# 4       5            Suicide Squad  Action,Adventure,Fantasy  1970
# ..    ...                      ...                       ...   ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery  1970
# 996   997          Hostel: Part II                    Horror  1970
# 997   998   Step Up 2: The Streets       Drama,Music,Romance  1970
# 998   999             Search Party          Adventure,Comedy  1970
# 999  1000               Nine Lives     Comedy,Family,Fantasy  1970
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'new_year', 'Description', 'Director',
#        'Actors', 'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df=df.rename({"new_year":"Year"},axis=1)

# %%
df
# Out:
#      Rank                    Title                     Genre  Year  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  1970
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi  1970
# 2       3                    Split           Horror,Thriller  1970
# 3       4                     Sing   Animation,Comedy,Family  1970
# 4       5            Suicide Squad  Action,Adventure,Fantasy  1970
# ..    ...                      ...                       ...   ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery  1970
# 996   997          Hostel: Part II                    Horror  1970
# 997   998   Step Up 2: The Streets       Drama,Music,Romance  1970
# 998   999             Search Party          Adventure,Comedy  1970
# 999  1000               Nine Lives     Comedy,Family,Fantasy  1970
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.groupby('Year')['Votes'].mean().nlargest(1)
# Out:
# Year
# 2012    285226.09375
# Name: Votes, dtype: float64

# %%
sns.barplot(x='Year',y='Votes',data=df)
plt.title('Votes_BY_Year')
# Out:
# Text(0.5, 1.0, 'Votes_BY_Year')

# %%
df.groupby('Year')['Votes'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
#                      ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
# Name: Rating, Length: 644, dtype: float64

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.sort_values(by='Runtime (Minutes)',ascending=False).head(10)[['Title','Runtime (Minutes)']]
# Out:
#                                         Title  Runtime (Minutes)
# 828                                Grindhouse                191
# 88                          The Hateful Eight                187
# 965                             Inland Empire                180
# 311                            La vie d'Adèle                180
# 82                    The Wolf of Wall Street                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169
# 36                               Interstellar                169

# %%
df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Title'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df1=df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Runtime (Minutes)',y='Title',data=df1)
plt.xticks(rotation=60)
# plt.xlables('Title')
# plt.ylables('runtime')
plt.show()

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
sns.countplot(x='Year',data=df)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='count'>

# %%
df.Year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df[df['Revenue (Millions)'].max()==df['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
df.nlargest(1,'Revenue (Millions)')
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore  \
# 50                136     8.1  661608              936.63       81.0
#
#                            Year1
# 50 1970-01-01 00:00:00.000002015

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.sort_values(by='Rating',ascending=False).head(10)[['Title','Director','Rating']].set_index('Title').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Title'>

# %%
df1=df.sort_values(by='Rating',ascending=False).head(10)[['Title','Director','Rating']].set_index('Title')

# %%
df1
# Out:
#                            Director  Rating
# Title
# The Dark Knight   Christopher Nolan     9.0
# Inception         Christopher Nolan     8.8
# Dangal                Nitesh Tiwari     8.8
# Interstellar      Christopher Nolan     8.6
# Kimi no na wa        Makoto Shinkai     8.6
# The Intouchables    Olivier Nakache     8.6
# Whiplash            Damien Chazelle     8.5
# The Prestige      Christopher Nolan     8.5
# The Departed        Martin Scorsese     8.5
# Taare Zameen Par         Aamir Khan     8.5

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df1.index,y='Rating',data=df1,hue='Director',dodge=False)
plt.xticks(rotation=60)
plt.xlabel('Titleee',fontsize=14)
plt.ylabel('rating',fontsize=14)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df1=df.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']]

# %%
sns.barplot(x='Revenue (Millions)',y='Title',data=df1)
# Out:
# <AxesSubplot: xlabel='Revenue (Millions)', ylabel='Title'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.groupby('Year')['Rating'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=df)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
df.corr()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_32904\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue (Millions)  Metascore
# ...

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_32904\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Year1'],
#       dtype='object')

# %%
df.Rating
# Out:
# 0      8.1
# 1      7.0
# 2      7.3
# 3      7.2
# 4      6.2
#       ...
# 995    6.2
# 996    5.5
# 997    6.2
# 998    5.6
# 999    5.3
# Name: Rating, Length: 1000, dtype: float64

# %%
def rat(rating):
    if rating>=0 and rating<5:
        return 'Average'
    elif rating>=5 and rating<=6:
        return 'Good'
    else: return 'Excellent'

# %%
df.Rating.dtype
# Out:
# dtype('float64')

# %%
df.Rating.unique()
# Out:
# array([8.1, 7. , 7.3, 7.2, 6.2, 6.1, 8.3, 6.4, 7.1, 7.5, 7.8, 7.9, 7.7,
#        6.6, 8.2, 6.7, 8. , 6.5, 5.3, 6.8, 4.7, 5.9, 6.3, 5.6, 8.6, 7.6,
#        6.9, 2.7, 3.7, 5.8, 9. , 7.4, 4.1, 8.5, 8.8, 5.4, 6. , 5.7, 8.4,
#        5.2, 5.5, 4.8, 3.9, 4.9, 5.1, 5. , 4.3, 4.6, 4.2, 4. , 3.2, 4.5,
#        1.9, 3.5, 4.4])

# %%
df
# Out:
# 0      <function rat at 0x0000015D3706ED40>
# 1      <function rat at 0x0000015D3706ED40>
# 2      <function rat at 0x0000015D3706ED40>
# 3      <function rat at 0x0000015D3706ED40>
# 4      <function rat at 0x0000015D3706ED40>
#                        ...
# 995    <function rat at 0x0000015D3706ED40>
# 996    <function rat at 0x0000015D3706ED40>
# 997    <function rat at 0x0000015D3706ED40>
# 998    <function rat at 0x0000015D3706ED40>
# 999    <function rat at 0x0000015D3706ED40>
# Name: Rating, Length: 1000, dtype: object

# %%
df['Remarks']=df.Rating.apply(rat)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.Remarks.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Remarks'],
#       dtype='object')

# %%
(df['Genre'].str.contains('action',case=False)).sum()
# Out:
# 303

# %%
df.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore    Remarks
# 0     8.1  757074              333.13       76.0  Excellent
# 1     7.0  485820              126.46       65.0  Excellent

# %%
df['Genre1']=df['Genre'].str.split(',')

# %%
l=[]
d=[]
for item in df['Genre1']:
    l.append(item)
    for item1 in item:
        d.append(item1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 l=[]
#       2 d=[]
# ----> 3 for item in df['Genre1']:
#       4     l.append(item)
#       5     for item1 in item:
#
# NameError: name 'df' is not defined

# %%
l=[]
d=[]
for item in df['Genre1']:
    for item1 in item:
        if item1 not in d:
            d.append(item1)

# %%
f=[]
for item in df['Genre1']:
    for item1 in item:
        f.append(item1)

# %%
from collections import Counter

# %%
Counter(f)
# Out:
# Counter({'Action': 303,
#          'Adventure': 259,
#          'Sci-Fi': 120,
#          'Mystery': 106,
#          'Horror': 119,
#          'Thriller': 195,
#          'Animation': 49,
#          'Comedy': 279,
#          'Family': 51,
#          'Fantasy': 101,
#          'Drama': 513,
#          'Music': 16,
#          'Biography': 81,
#          'Romance': 141,
#          'History': 29,
#          'Crime': 150,
#          'Western': 7,
#          'War': 13,
#          'Musical': 5,
#          'Sport': 18})
