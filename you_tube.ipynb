# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\saura\OneDrive\Desktop\top-5000-youtube-channels.csv')

# %%
df
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
df.shape
# Out:
# (5000, 6)

# %%
print('rows',df.shape[0])
# Out:
# rows 5000

# %%
print('columns',df.shape[1])
# Out:
# columns 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
df.head(2)
# Out:
#   Rank Grade Channel name Video Uploads Subscribers  Video views
# 0  1st  A++        Zee TV         82757    18752951  20869786591
# 1  2nd  A++      T-Series         12661    61196302  47548839843

# %%
df=df.apply(pd.to_numeric,errors='coerce')
# pd.to_numeric()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           0 non-null      float64
#  1   Grade          0 non-null      float64
#  2   Channel name   0 non-null      float64
#  3   Video Uploads  4994 non-null   float64
#  4   Subscribers    4613 non-null   float64
#  5   Video views    5000 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 234.5 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   int64
#  5   Video views    5000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 234.5+ KB

# %%
df.Subscribers=pd.to_numeric(df.Subscribers)

# %%
df[df.Subscribers=='-- ']
# Out:
# Empty DataFrame
# Columns: [Rank, Grade, Channel name, Video Uploads, Subscribers, Video views]
# Index: []

# %%
df.Subscribers=df.Subscribers.str.replace('-- ','0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   int64
#  5   Video views    5000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 234.5+ KB

# %%
df.head(2)
# Out:
#   Rank Grade Channel name Video Uploads  Subscribers  Video views
# 0  1st  A++        Zee TV         82757     18752951  20869786591
# 1  2nd  A++      T-Series         12661     61196302  47548839843

# %%
pd.to_numeric(df['Video Uploads'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\lib.pyx:2363, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "--"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 pd.to_numeric(df['Video Uploads'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
df[['Video Uploads','Video views']]=df[['Video Uploads','Video views']].apply(pd.to_numeric,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  4994 non-null   float64
#  4   Subscribers    5000 non-null   int64
#  5   Video views    5000 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 234.5+ KB

# %%
df.head()
# Out:
#   Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0  1st  A++                       Zee TV        82757.0     18752951
# 1  2nd  A++                     T-Series        12661.0     61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes          373.0     19238251
# 3  4th  A++                    SET India        27323.0     31180559
# 4  5th  A++                          WWE        36756.0     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.dropna(inplace=True)
df.isnull().sum()
df['Video Uploads']=df['Video Uploads'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           4994 non-null   object
#  1   Grade          4994 non-null   object
#  2   Channel name   4994 non-null   object
#  3   Video Uploads  4994 non-null   int32
#  4   Subscribers    4994 non-null   object
#  5   Video views    4994 non-null   int64
# dtypes: int32(1), int64(1), object(4)
# memory usage: 253.6+ KB

# %%
df.iloc[:-5]
# Out:
#          Rank Grade                      Channel name  Video Uploads  \
# 0         1st  A++                             Zee TV          82757
# 1         2nd  A++                           T-Series          12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes            373
# 3         4th  A++                          SET India          27323
# 4         5th  A++                                WWE          36756
# ...       ...   ...                               ...            ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel            208
# 4991  4,992nd   B+               Toys to Learn Colors             11
# 4992  4,993rd   B+                              КАZКА             25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…           1055
# 4994  4,995th   B+                      Wings Marathi           1735
#
#       Subscribers  Video views
# 0        18752951  20869786591
# 1        61196302  47548839843
# 2        19238251   9793305082
# ...

# %%
df.tail(-5)
# Out:
#          Rank Grade           Channel name  Video Uploads  Subscribers  \
# 5         6th  A++              Movieclips          30243     17149705
# 6         7th  A++              netd müzik           8500     11373567
# 7         8th  A++   ABS-CBN Entertainment         100147     12149206
# 8         9th  A++         Ryan ToysReview           1140     16082927
# 9        10th  A++             Zee Marathi          74607      2841811
# ...       ...   ...                    ...            ...          ...
# 4995  4,996th   B+          Uras Benlioğlu            706      2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD            797      1055091
# 4997  4,998th   B+             Mastersaint            110      3265735
# 4998  4,999th   B+          Bruce McIntosh           3475        32990
# 4999  5,000th   B+               SehatAQUA            254        21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# ...

# %%
pd.options.display.float_format='{:.2f}'.format
df.describe()
# Out:
#        Video Uploads  Subscribers    Video views
# count        4994.00      4994.00        4994.00
# mean         3859.46   2419952.04  1072617597.21
# std         17085.87   3837331.61  2004762201.21
# min             1.00         0.00          75.00
# 25%           141.00    459900.75   186315479.25
# 50%           443.00   1208188.00   482450118.50
# 75%          1501.75   2726011.25  1124960779.75
# max        422326.00  65995310.00 47548839843.00

# %%
df.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %%
df.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers       int64
# Video views       int64
# dtype: object

# %%
df.Rank
df.Rank=df.Rank.str[0:-2].str.replace(',','')
df.Rank=pd.to_numeric(df.Rank,errors='coerce')
pd.set_option('display.max_rows',1000)

# %%
df.head(1000)
# Out:
#      Rank Grade                          Channel name  Video Uploads  \
# 0          A++                                 Zee TV          82757
# 1          A++                               T-Series          12661
# 2          A++             Cocomelon - Nursery Rhymes            373
# 3          A++                              SET India          27323
# 4          A++                                    WWE          36756
# 5          A++                             Movieclips          30243
# 6          A++                             netd müzik           8500
# 7          A++                  ABS-CBN Entertainment         100147
# 8          A++                        Ryan ToysReview           1140
# 9          A++                            Zee Marathi          74607
# 10          A+                        5-Minute Crafts           2085
# 11          A+                        Canal KondZilla            822
# 12          A+                       Like Nastya Vlog            150
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           4994 non-null   int64
#  1   Grade          4994 non-null   object
#  2   Channel name   4994 non-null   object
#  3   Video Uploads  4994 non-null   int32
#  4   Subscribers    4994 non-null   object
#  5   Video views    4994 non-null   int64
# dtypes: int32(1), int64(2), object(3)
# memory usage: 253.6+ KB

# %%
df
# Out:
#       Rank Grade                Channel name  Video Uploads Subscribers  \
# 0        1  A++                       Zee TV          82757    18752951
# 1        2  A++                     T-Series          12661    61196302
# 2        3  A++   Cocomelon - Nursery Rhymes            373    19238251
# 3        4  A++                    SET India          27323    31180559
# 4        5  A++                          WWE          36756    32852346
# ...    ...   ...                         ...            ...         ...
# 4995  4996   B+               Uras Benlioğlu            706     2072942
# 4996  4997   B+            HI-TECH MUSIC LTD            797     1055091
# 4997  4998   B+                  Mastersaint            110     3265735
# 4998  4999   B+               Bruce McIntosh           3475       32990
# 4999  5000   B+                    SehatAQUA            254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# 3     22675948293
# ...

# %%
df[df['Channel name'].str.contains('India')]
# Out:
#       Rank Grade                          Channel name  Video Uploads  \
# 3        4  A++                              SET India          27323
# 48      49   A+                       Sony Music India           2204
# 64      65    A                     SonyMusicIndiaVEVO           2958
# 86      87    A              Dehati India NonVeg Masti            612
# 153    154    A                             ZeeQ India            336
# 236    237    A                                IndiaTV         120243
# 275    276    A                            IndiaiStore              6
# 351    352    A                      Think Music India           2356
# 594    595    A                      Dance India Dance           3316
# 709    710    A                           SamsungIndia            183
# 783    784    A                 WamIndia Movie Talkies            118
# 1014  1015    A                          Netflix India            450
# ...

# %%
df.Grade.unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
df.Grade=df.Grade.map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})

# %%
df.Grade
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4995    1
# 4996    1
# 4997    1
# 4998    1
# 4999    1
# Name: Grade, Length: 4994, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           4994 non-null   int64
#  1   Grade          4994 non-null   int64
#  2   Channel name   4994 non-null   object
#  3   Video Uploads  4994 non-null   int32
#  4   Subscribers    4994 non-null   object
#  5   Video views    4994 non-null   int64
# dtypes: int32(1), int64(3), object(2)
# memory usage: 253.6+ KB

# %%
df.groupby('Channel name')['Video views'].mean()
# Out:
# Channel name
# #Desenhos Kids BR                84041146.00
# #FIRST WINGS FILM PRODUCTION     12678949.00
# #Mentale Zuflucht               363411371.00
# #Mind Warehouse                1337876967.00
# #Refugio Mental                1262196983.00
#                                     ...
# 핑크퐁 (인기 동요・동화)                 1595352760.00
# 허팝Heopop                       1690027375.00
# 헤이지니 Hey Jini                   455023697.00
# 헬로카봇 - hello carbot…            329191509.00
# 흔한남매                            119653177.00
# Name: Video views, Length: 4987, dtype: float64

# %%
df.columns
df['avg_view']=df['Video views']/df['Video Uploads']

# %%
df.avg_view=df.avg_view.round().astype('int')

# %%
df
# Out:
#       Rank  Grade                Channel name  Video Uploads Subscribers  \
# 0        1      5                      Zee TV          82757    18752951
# 1        2      5                    T-Series          12661    61196302
# 2        3      5  Cocomelon - Nursery Rhymes            373    19238251
# 3        4      5                   SET India          27323    31180559
# 4        5      5                         WWE          36756    32852346
# ...    ...    ...                         ...            ...         ...
# 4995  4996      1              Uras Benlioğlu            706     2072942
# 4996  4997      1           HI-TECH MUSIC LTD            797     1055091
# 4997  4998      1                 Mastersaint            110     3265735
# 4998  4999      1              Bruce McIntosh           3475       32990
# 4999  5000      1                   SehatAQUA            254       21172
#
#       Video views  avg_view
# 0     20869786591    252182
# 1     47548839843   3755536
# ...

# %%
df.groupby('Channel name').mean()['Video Uploads'].sort_values(ascending=False).head(5)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_22468\2182469104.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Channel name').mean()['Video Uploads'].sort_values(ascending=False).head(5)
# Channel name
# AP Archive   422326.00
# YTN NEWS     355996.00
# SBS Drama    335521.00
# GMA News     269065.00
# MLB          267649.00
# Name: Video Uploads, dtype: float64

# %%
df.corr()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_22468\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Rank  Grade  Video Uploads  Video views  avg_view
# Rank           1.00  -0.86          -0.07        -0.39     -0.15
# Grade         -0.86   1.00           0.09         0.46      0.15
# Video Uploads -0.07   0.09           1.00         0.09     -0.06
# Video views   -0.39   0.46           0.09         1.00      0.30
# avg_view      -0.15   0.15          -0.06         0.30      1.00

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_22468\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'avg_view'],
#       dtype='object')

# %%
# df.groupby('Grade')['Video Uploads'].mean().sort_values(ascending=False).plot(kind='bar')

# %%
sns.barplot(data=df,x='Grade',y='Video Uploads')
# Out:
# <AxesSubplot: xlabel='Grade', ylabel='Video Uploads'>

# %%
sns.barplot(data=df,x='Grade',y='avg_view')
# Out:
# <AxesSubplot: xlabel='Grade', ylabel='avg_view'>

# %%
df.info()
# df.Subscribers=df.Subscribers.str.replace('-- ','0').astype('int')
sns.barplot(data=df,y='Subscribers',x='Grade')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           4994 non-null   int64
#  1   Grade          4994 non-null   int64
#  2   Channel name   4994 non-null   object
#  3   Video Uploads  4994 non-null   int32
#  4   Subscribers    4994 non-null   int32
#  5   Video views    4994 non-null   int64
#  6   avg_view       4994 non-null   int32
# dtypes: int32(3), int64(3), object(1)
# memory usage: 382.6+ KB
# <AxesSubplot: xlabel='Grade', ylabel='Subscribers'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4994 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           4994 non-null   int64
#  1   Grade          4994 non-null   int64
#  2   Channel name   4994 non-null   object
#  3   Video Uploads  4994 non-null   int32
#  4   Subscribers    4994 non-null   int32
#  5   Video views    4994 non-null   int64
#  6   avg_view       4994 non-null   int32
# dtypes: int32(3), int64(3), object(1)
# memory usage: 382.6+ KB

# %%
sns.barplot(data=df,x='Grade',y='Video views')
# Out:
# <AxesSubplot: xlabel='Grade', ylabel='Video views'>

# %%
df.groupby('Grade')['Video views'].sum().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Grade'>
